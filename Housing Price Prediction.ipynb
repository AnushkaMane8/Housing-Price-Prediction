# %% [markdown]
# REAL ESTATE PROJECT

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
housing = pd.read_excel("data.xlsx")

# %%
housing.head() #top 5 rows
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
 housing.info()#total entries
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       501 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
housing['CHAS'].value_counts()#how many time value is repeated
# Out:
# 0    471
# 1     35
# Name: CHAS, dtype: int64

# %%
housing.describe()#std:amount of value spread from mean
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  501.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.286818
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.703798
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885000
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208000
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.629000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
housing.hist(bins=50, figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f496346f710>,
# ...
#       dtype=object)

# %%
#we need seperate data for training and testing...

# %% [markdown]
# Train-Test splitting

# %%
import numpy as np
def split_train_test(data, test_ratio):
  np.random.seed(42)# 
  shuffled = np.random.permutation(len(data))
  print(shuffled)#shuffled is used to shuffled data in random way
  test_set_size = int(len(data) * test_ratio)
  test_indices = shuffled[:test_set_size]
  train_indices = shuffled[test_set_size:]
  return data.iloc[train_indices], data.iloc[test_indices]

# %%
train_set, test_set = split_train_test(housing, 0.2)
# Out:
# [173 274 491  72 452  76 316 140 471 500 218   9 414  78 323 473 124 388
#  195 448 271 278  30 501 421 474  79 454 210 497 172 320 375 362 467 153
#    2 336 208  73 496 307 204  68  90 390  33  70 470   0  11 281  22 101
#  268 485 442 290  84 245  63  55 229  18 351 209 395  82  39 456  46 481
#  444 355  77 398 104 203 381 489  69 408 255 392 312 234 460 324  93 137
#  176 417 131 346 365 132 371 412 436 411  86  75 477  15 332 423  19 325
#  335  56 437 409 334 181 227 434 180  25 493 238 244 250 418 117  42 322
#  347 182 155 280 126 329  31 113 148 432 338  57 194  24  17 298  66 211
#  404  94 154 441  23 225 433 447   5 116  45  16 468 360   3 405 185  60
#  110 321 265  29 262 478  26   7 492 108  37 157 472 118 114 175 192 272
#  144 373 383 356 277 220 450 141 369  67 361 168 499 394 400 193 249 109
#  420 145  92 152 222 304  83 248 165 163 199 231  74 311 455 253 119 284
#  302 483 357 403 228 261 237 386 476  36 196 139 368 247 287 378  59 111
# ...

# %%
print("Rows in train set: {len(train_set)}\nRows in test set: {len(test_set)}\n")
# Out:
# Rows in train set: {len(train_set)}
# Rows in test set: {len(test_set)}

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(housing, test_size=0.2, random_state=42)
print(f"Rows in train set: {len(train_set)}\nRows in test set: {len(test_set)}\n")
# Out:
# Rows in train set: 404
# Rows in test set: 102

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index, test_index in split.split(housing, housing['CHAS']):
  strat_train_set = housing.loc[train_index]
  strat_test_set = housing.loc[test_index]

# %%
 strat_test_set
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 342   0.02498   0.0   1.89     0  0.518  6.540   59.7  6.2669    1  422
# 379  17.86670   0.0  18.10     0  0.671  6.223  100.0  1.3861   24  666
# 223   0.61470   0.0   6.20     0  0.507  6.618   80.8  3.2721    8  307
# 219   0.11425   0.0  13.89     1  0.550  6.373   92.4  3.3633    5  276
# 48    0.25387   0.0   6.91     0  0.448  5.399   95.3  5.8700    3  233
# ..        ...   ...    ...   ...    ...    ...    ...     ...  ...  ...
# 88    0.05660   0.0   3.41     0  0.489  7.007   86.3  3.4217    2  270
# 466   3.77498   0.0  18.10     0  0.655  5.952   84.7  2.8715   24  666
# 52    0.05360  21.0   5.64     0  0.439  6.511   21.1  6.8147    4  243
# 121   0.07165   0.0  25.65     0  0.581  6.004   84.1  2.1974    2  188
# 218   0.11069   0.0  13.89     1  0.550  5.951   93.8  2.8893    5  276
#
#      PTRATIO       B  LSTAT  MEDV
# 342     15.9  389.96   8.65  16.5
# ...

# %%
 strat_test_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102 entries, 342 to 218
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     102 non-null    float64
#  1   ZN       102 non-null    float64
#  2   INDUS    102 non-null    float64
#  3   CHAS     102 non-null    int64
#  4   NOX      102 non-null    float64
#  5   RM       101 non-null    float64
#  6   AGE      102 non-null    float64
#  7   DIS      102 non-null    float64
#  8   RAD      102 non-null    int64
#  9   TAX      102 non-null    int64
#  10  PTRATIO  102 non-null    float64
#  11  B        102 non-null    float64
#  12  LSTAT    102 non-null    float64
#  13  MEDV     102 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 12.0 KB

# %%
 strat_test_set['CHAS'].value_counts()
# Out:
# 0    95
# 1     7
# Name: CHAS, dtype: int64

# %% [markdown]
# corelation
# # New Section

# %%
corr_matrix = housing.corr()#up to which extend final value depends on that particular feature

# %%
corr_matrix['MEDV'].sort_values(ascending=False)
# Out:
# MEDV       1.000000
# RM         0.694862
# ZN         0.360445
# B          0.333461
# DIS        0.249929
# CHAS       0.175260
# AGE       -0.376955
# RAD       -0.381626
# CRIM      -0.388305
# NOX       -0.427321
# TAX       -0.468536
# INDUS     -0.483725
# PTRATIO   -0.507787
# LSTAT     -0.737663
# Name: MEDV, dtype: float64

# %%
from pandas.plotting import scatter_matrix
attributes = ["MEDV", "LSTAT","RM","ZN"]
scatter_matrix(housing[attributes], figsize = (12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4962602890>,
# ...
#       dtype=object)

# %%
from pandas.plotting import scatter_matrix
attributes = ["MEDV", "LSTAT","RM","ZN",]
scatter_matrix(housing[attributes], figsize = (12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f496226d590>,
# ...
#       dtype=object)

# %%
from pandas.plotting import scatter_matrix
attributes = ["MEDV", "DIS","TAX","ZN",]
scatter_matrix(housing[attributes], figsize = (12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4961b29310>,
# ...
#       dtype=object)

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       501 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
housing.plot(kind="scatter", y="MEDV", x="RM", alpha=0.9)

# %%
housing.plot(kind="scatter", y="MEDV", x="LSTAT", alpha=0.9)

# %%
housing.plot(kind="scatter", y="MEDV", x="CRIM", alpha=0.9)

# %%
housing.plot(kind="scatter", y="MEDV", x="ZN", alpha=0.9)

# %%
housing.plot(kind="scatter", y="MEDV", x="INDUS", alpha=0.9)

# %%
housing.plot(kind="scatter", y="MEDV", x="CHAS", alpha=0.9)

# %%
housing.plot(kind="scatter", y="MEDV", x="DIS", alpha=0.9)

# %%
 housing = strat_train_set.drop("MEDV" , axis=1)
 housing_labels = strat_train_set["MEDV"].copy()

# %% [markdown]
# ***Trying*** **out** *italicised text* **attribute** **combinations**

# %%
housing["TAXRM"]=housing['TAX']/housing['RM']

# %%
print(housing["TAXRM"])
# Out:
# 254     51.571709
# 348     42.200452
# 476    102.714374
# 321           NaN
# 326     45.468948
#           ...
# 155     65.507152
# 423    109.126659
# 98      35.294118
# 455    102.068966
# 216     46.875000
# Name: TAXRM, Length: 404, dtype: float64

# %%
 housing.head()
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 254  0.04819  80.0   3.64     0  0.392  6.108  32.0  9.2203    1  315
# 348  0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280
# 476  4.87141   0.0  18.10     0  0.614  6.484  93.6  2.3053   24  666
# 321  0.18159   0.0   7.38     0  0.493    NaN  54.3  4.5404    5  287
# 326  0.30347   0.0   7.38     0  0.493  6.312  28.9  5.4159    5  287
#
#      PTRATIO       B  LSTAT       TAXRM
# 254     16.4  392.89   6.57   51.571709
# 348     17.0  390.94   5.99   42.200452
# 476     20.2  396.21  18.68  102.714374
# 321     19.6  396.90   6.87         NaN
# 326     19.6  396.90   6.15   45.468948

# %% [markdown]
# # New Section

# %% [markdown]
# **Missing** **attributes**

# %%
#1.How to tackle with missing attributes
#1.get rid of missing data points
#2.get rid of complete attributes
#3.set the value to some value

# %%
housing.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  400.000000
# mean     3.602814   10.836634   11.344950    0.069307    0.558064    6.282185
# std      8.099383   22.150636    6.877817    0.254290    0.116875    0.713742
# min      0.006320    0.000000    0.740000    0.000000    0.389000    3.561000
# 25%      0.086962    0.000000    5.190000    0.000000    0.453000    5.878750
# 50%      0.286735    0.000000    9.900000    0.000000    0.538000    6.209000
# 75%      3.731923   12.500000   18.100000    0.000000    0.631000    6.632000
# max     73.534100  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    69.039851    3.746210    9.735149  412.341584   18.473267  353.392822
# ...

# %% [markdown]
# **scikit** **learn**

# %%
#primarily three types of object
#1.estimators-based on data set
#fit dataset and transformer method 
#2.transformer-
#3.predictor-Linear Regression model fit and predict

# %%
a=housing.dropna(subset=["RM"])
a.shape
# Out:
# (400, 14)

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 404 entries, 254 to 216
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     404 non-null    float64
#  1   ZN       404 non-null    float64
#  2   INDUS    404 non-null    float64
#  3   CHAS     404 non-null    int64
#  4   NOX      404 non-null    float64
#  5   RM       400 non-null    float64
#  6   AGE      404 non-null    float64
#  7   DIS      404 non-null    float64
#  8   RAD      404 non-null    int64
#  9   TAX      404 non-null    int64
#  10  PTRATIO  404 non-null    float64
#  11  B        404 non-null    float64
#  12  LSTAT    404 non-null    float64
#  13  TAXRM    400 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 47.3 KB

# %%
housing.drop("RM",axis=1)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX   AGE     DIS  RAD  TAX  PTRATIO  \
# 254  0.04819  80.0   3.64     0  0.392  32.0  9.2203    1  315     16.4
# 348  0.01501  80.0   2.01     0  0.435  29.7  8.3440    4  280     17.0
# 476  4.87141   0.0  18.10     0  0.614  93.6  2.3053   24  666     20.2
# 321  0.18159   0.0   7.38     0  0.493  54.3  4.5404    5  287     19.6
# 326  0.30347   0.0   7.38     0  0.493  28.9  5.4159    5  287     19.6
# ..       ...   ...    ...   ...    ...   ...     ...  ...  ...      ...
# 155  3.53501   0.0  19.58     1  0.871  82.6  1.7455    5  403     14.7
# 423  7.05042   0.0  18.10     0  0.614  85.1  2.0218   24  666     20.2
# 98   0.08187   0.0   2.89     0  0.445  36.9  3.4952    2  276     18.0
# 455  4.75237   0.0  18.10     0  0.713  86.5  2.4358   24  666     20.2
# 216  0.04560   0.0  13.89     1  0.550  56.0  3.1121    5  276     16.4
#
#           B  LSTAT       TAXRM
# 254  392.89   6.57   51.571709
# 348  390.94   5.99   42.200452
# ...

# %%
housing.drop("RM",axis=1).shape
# Out:
# (404, 13)

# %%
median = housing["RM"].median()

# %%
median
# Out:
# 6.209

# %%
housing["RM"].fillna(median)
# Out:
# 254    6.108
# 348    6.635
# 476    6.484
# 321    6.209
# 326    6.312
#        ...
# 155    6.152
# 423    6.103
# 98     7.820
# 455    6.525
# 216    5.888
# Name: RM, Length: 404, dtype: float64

# %%
 from sklearn.impute import SimpleImputer
 imputer = SimpleImputer(strategy="median")
 imputer.fit(housing)
# Out:
# SimpleImputer(strategy='median')

# %%
  imputer.statistics_
# Out:
# array([2.86735000e-01, 0.00000000e+00, 9.90000000e+00, 0.00000000e+00,
#        5.38000000e-01, 6.20900000e+00, 7.82000000e+01, 3.12220000e+00,
#        5.00000000e+00, 3.37000000e+02, 1.90000000e+01, 3.90955000e+02,
#        1.15700000e+01, 5.38588025e+01])

# %%
x = imputer.transform(housing)

# %%
housing_tr = pd.DataFrame(x, columns=housing.columns)

# %%
strat_test_set['CHAS'].value_counts()
# Out:
# 0    95
# 1     7
# Name: CHAS, dtype: int64

# %%
  strat_test_set['CHAS'].value_counts()
# Out:
# 0    95
# 1     7
# Name: CHAS, dtype: int64

# %%
a = housing.dropna(subset=["RM"])
a.shape
# Out:
# (400, 14)

# %%
housing["RM"].fillna(median)
# Out:
# 254    6.108
# 348    6.635
# 476    6.484
# 321    6.209
# 326    6.312
#        ...
# 155    6.152
# 423    6.103
# 98     7.820
# 455    6.525
# 216    5.888
# Name: RM, Length: 404, dtype: float64

# %% [markdown]
# ### New section
#  ***scikit*** ***learn*** ***design***
#  primarily three types of the object:
#  Estimators:It estimates some parameters based on dataset
#  transformer---transform method takes input and display output on given learning
#  predictor----linear regression model is an example of predictor.It fit() and predict() are two common function

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
my_pipeline = Pipeline([('imputer' , SimpleImputer(strategy = "median")),
                       ('std_scaler', StandardScaler()),])

# %%
housing_num_tr = my_pipeline.fit_transform(housing_tr)

# %%
housing_num_tr.shape
# Out:
# (404, 14)

# %%
housing_num_tr.shape
# Out:
# (404, 14)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()

#model = LinearRegression()
#model =DecisionTreeRegressor()
model.fit(housing_num_tr, housing_labels)
# Out:
# RandomForestRegressor()

# %%
some_data = housing.iloc[:5]

# %%
some_labels = housing_labels.iloc[:5]

# %%
prepared_data = my_pipeline.transform(some_data)

# %%
model.predict(prepared_data)
# Out:
# array([22.586, 25.44 , 16.254, 23.143, 23.431])

# %%
some_labels
# Out:
# 254    21.9
# 348    24.5
# 476    16.7
# 321    23.1
# 326    23.0
# Name: MEDV, dtype: float64

# %%
list(some_labels)
# Out:
# [21.9, 24.5, 16.7, 23.1, 23.0]

# %% [markdown]
# ##evaluating model

# %%
from sklearn.metrics import mean_squared_error
housing_predictions = model.predict(housing_num_tr)
mse = mean_squared_error(housing_labels, housing_predictions)
rmse = np.sqrt(mse)

# %%
mse
# Out:
# 1.3656981658415839

# %% [markdown]
# ##using better valuation technique

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model, housing_num_tr, housing_labels, scoring="neg_mean_squared_error",cv=10)
rmse_scores = np.sqrt(-scores)

# %%
rmse_scores
# Out:
# array([2.86818477, 2.91109108, 4.43023236, 2.62423439, 3.3042153 ,
#        2.55846913, 4.67479769, 3.28936957, 3.3707069 , 3.24960118])

# %%
def print_scores(scores):
  print("Scores:", scores)
  print("Mean:", scores.mean())
  print("Standard deviation:", scores.std())

# %%
print_scores(rmse_scores)
# Out:
# Scores: [2.86818477 2.91109108 4.43023236 2.62423439 3.3042153  2.55846913
#  4.67479769 3.28936957 3.3707069  3.24960118]
# Mean: 3.3280902376025
# Standard deviation: 0.6716781428861776

# %%
#X_test = strat_test_set.drop("MEDV", axis=1)
#Y_test = strat_test_set["MEDV"].copy()
#X_test_prepared = my_pipeline.transform(X_test)
#final_predictions = model.predict(X_test_prepared)
#final_mse = mean_squared_error(Y_test, final_predictions)
#final_rmse = np.sqrt(final_mse)
